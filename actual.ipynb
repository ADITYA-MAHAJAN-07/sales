# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# Load the sales data
sales_data = pd.read_csv('Advertising.csv')

# %%
sales_data.head()
sales_data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Data preprocessing
sales_data = pd.get_dummies(sales_data, drop_first=True)

# %%
# Split the data into training and testing sets
X = sales_data.drop(['Sales'], axis=1)
y = sales_data['Sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Train the linear regression model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred_lr = regressor.predict(X_test)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))
r2_lr = r2_score(y_test, y_pred_lr)

# %%
print(y_test, y_pred_lr)
# Out:
# 18     11.3
# 170     8.4
# 107     8.7
# 98     25.4
# 177    11.7
# 182     8.7
# 5       7.2
# 146    13.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    10.5
# 154    15.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     14.9
# 159    12.9
# 60      8.1
# 123    15.2
# 179    12.6
# 185    22.6
# 122    11.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      12.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64 [10.24664397  7.3067958   7.01313011 24.0629912  11.84538583  6.3623126
#  12.97367539 15.01392577 10.95137181 16.2302401  22.94764396  9.07892877
#  10.29830431 15.372556   11.63358138 12.38729183 18.91996453 10.72601207
#  16.03372676 17.36589369 23.85225051  9.51048184 15.25366204 12.2528663
#   5.81346738 15.19998588 12.12398331 20.74762723 13.36651757  9.16548788
# ...

# %%
# Train the decision tree regressor model
dt_regressor = DecisionTreeRegressor(random_state=0)
dt_regressor.fit(X_train, y_train)
y_pred_dt = dt_regressor.predict(X_test)
rmse_dt = np.sqrt(mean_squared_error(y_test, y_pred_dt))
r2_dt = r2_score(y_test, y_pred_dt)

# %%
print(y_test, y_pred_dt)
# Out:
# 18     11.3
# 170     8.4
# 107     8.7
# 98     25.4
# 177    11.7
# 182     8.7
# 5       7.2
# 146    13.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    10.5
# 154    15.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     14.9
# 159    12.9
# 60      8.1
# 123    15.2
# 179    12.6
# 185    22.6
# 122    11.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      12.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64 [10.7 10.1  8.8 24.4 12.8  8.6  6.6 12.5  9.3 16.6 24.4 10.9 10.3 15.5
#  10.7 11.9 15.9  6.6 12.6 17.4 25.5 10.1 16.6 13.2  8.6 14.2 14.5 20.7
#  10.1  6.9 12.6 22.4 15.7 22.3  5.5  7.6  9.7 14.8 11.8  6.9]

# %%
# Train the random forest regressor model
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=0)
rf_regressor.fit(X_train, y_train)
y_pred_rf = rf_regressor.predict(X_test)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

# %%
print(y_test, y_pred_rf)
# Out:
# 18     11.3
# 170     8.4
# 107     8.7
# 98     25.4
# 177    11.7
# 182     8.7
# 5       7.2
# 146    13.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    10.5
# 154    15.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     14.9
# 159    12.9
# 60      8.1
# 123    15.2
# 179    12.6
# 185    22.6
# 122    11.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      12.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64 [10.551  9.516  9.365 24.796 12.562  9.04   7.368 12.623  8.696 16.439
#  24.469 10.298 10.863 15.325 11.508 12.429 15.728  6.089 13.258 17.024
#  25.335 10.466 15.715 12.872  8.831 14.742 14.114 22.125 11.391  7.851
#  12.199 22.121 15.221 22.557  6.37   6.998  9.95  14.532 12.573  7.273]

# %%
# Print the evaluation metrics for each model
print('Linear Regression - RMSE:', rmse_lr, 'R2:', r2_lr)
print('Decision Tree Regressor - RMSE:', rmse_dt, 'R2:', r2_dt)
print('Random Forest Regressor - RMSE:', rmse_rf, 'R2:', r2_rf)
# Out:
# Linear Regression - RMSE: 2.1252030072958736 R2: 0.8564802143279249
# Decision Tree Regressor - RMSE: 1.3028814220795384 R2: 0.946058785993
# Random Forest Regressor - RMSE: 1.0458892986353774 R2: 0.9652397915358767

# %%
# Visualize the predicted vs actual sales for linear regression
plt.scatter(y_test, y_pred_lr)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Linear Regression - Actual vs Predicted Sales')
plt.show()

# %%
# Visualize the predicted vs actual sales for decision tree regressor
plt.scatter(y_test, y_pred_dt)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Decision Tree Regressor - Actual vs Predicted Sales')
plt.show()

# %%
# Visualize the predicted vs actual sales for random forest regressor
plt.scatter(y_test, y_pred_rf)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Random Forest Regressor - Actual vs Predicted Sales')
plt.show()

# %%
# Visualize the feature importances for random forest regressor
importances = pd.Series(rf_regressor.feature_importances_, index=X.columns)
importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importances')
plt.show()
